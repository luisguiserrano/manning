# %%
[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/luisguiserrano/Testing/blob/master/notebooks/test.ipynb)
# Out:
#   File "<ipython-input-2-210d43b313d3>", line 1
#     [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/luisguiserrano/Testing/blob/master/notebooks/test.ipynb)
#      ^
# SyntaxError: invalid syntax
